# %%
def solution(S):
    strHouse = list(S)
    n = len(strHouse)
    i_tank = 0

    i = 0
    while i < n:
        if strHouse[i] == 'H':
            # Check if we can place the tank to the right of the house
            if i + 1 < n and strHouse[i + 1] == '-':
                strHouse[i + 1] = 'T'
                i_tank += 1
                i += 2  # Move to the next potential house after placing tank to the right
            # If the right place is not available, place the tank to the left of the

# %%
def solution(S):
  strHouse = list(S)
  n = len(strHouse)
  i_tank = 0

  i = 0
  while i < n:
    if strHouse[i] == "-":
      strHouse[i] = "T"
    i +=1

  j = 1
  while j < n:
    if strHouse[j] == "H":
      if strHouse[j - 1] == "T" and strHouse[j + 1] == "T":
        strHouse[j + 1] = "T"

    j += 1

  k = 0
  while k < n - 1:
    if strHouse[k] == "T" and strHouse[k + 1] == "T":
      strHouse[k + 1] = "-"
    k += 1

  l = 1
  while l < n:
    if strHouse[l] == "H":
      if strHouse[l - 1] == "T" and strHouse[l + 1] == "T":
        strHouse[l -1] = "-"
    l += 1

  for x in strHouse:
    if x == "T":
      i_tank +=1

  print(strHouse)
  return i_tank


S = "-H-HH--"
print(solution(S))
# Out:
# ['-', 'H', 'T', 'H', 'H', 'T', '-']
# 2
