# %%
def isValidSudoku(board) -> bool:
  rows = [set() for _ in range(9)]
  columns = [set() for _ in range(9)]
  boxes = [set() for _ in range(9)]
  print(type(rows))
  print(rows)
  print(type(boxes))


  for i in range(9):
      for j in range(9):
          num = board[i][j]
          print(num)
          if num == '.':
              continue
          box_index = (i // 3) * 3 + (j // 3)
          # print("box_index: ",box_index)
          if num in rows[i] or num in columns[j] or num in boxes[box_index]:
              return False
          rows[i].add(num)
          columns[j].add(num)
          boxes[box_index].add(num)
          print("boxes: ", boxes)
  return True

# %%
board = [["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]

isValidSudoku(board)
# Out:
# <class 'list'>
# [set(), set(), set(), set(), set(), set(), set(), set(), set()]
# <class 'list'>
# 5
# boxes:  [{'5'}, set(), set(), set(), set(), set(), set(), set(), set()]
# 3
# boxes:  [{'5', '3'}, set(), set(), set(), set(), set(), set(), set(), set()]
# .
# .
# 7
# boxes:  [{'5', '3'}, {'7'}, set(), set(), set(), set(), set(), set(), set()]
# .
# .
# .
# .
# 6
# boxes:  [{'5', '6', '3'}, {'7'}, set(), set(), set(), set(), set(), set(), set()]
# .
# .
# 1
# boxes:  [{'5', '6', '3'}, {'7', '1'}, set(), set(), set(), set(), set(), set(), set()]
# 9
# boxes:  [{'5', '6', '3'}, {'7', '9', '1'}, set(), set(), set(), set(), set(), set(), set()]
# 5
# boxes:  [{'5', '6', '3'}, {'5', '7', '9', '1'}, set(), set(), set(), set(), set(), set(), set()]
# .
# .
# .
# .
# 9
# boxes:  [{'5', '6', '3', '9'}, {'5', '7', '9', '1'}, set(), set(), set(), set(), set(), set(), set()]
# 8
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, set(), set(), set(), set(), set(), set(), set()]
# .
# .
# .
# .
# 6
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, set(), set(), set(), set(), set(), set()]
# .
# 8
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'8'}, set(), set(), set(), set(), set()]
# .
# .
# .
# 6
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'8'}, {'6'}, set(), set(), set(), set()]
# .
# .
# .
# 3
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'8'}, {'6'}, {'3'}, set(), set(), set()]
# 4
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '8'}, {'6'}, {'3'}, set(), set(), set()]
# .
# .
# 8
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '8'}, {'6', '8'}, {'3'}, set(), set(), set()]
# .
# 3
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '8'}, {'6', '8', '3'}, {'3'}, set(), set(), set()]
# .
# .
# 1
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '8'}, {'6', '8', '3'}, {'3', '1'}, set(), set(), set()]
# 7
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'6', '8', '3'}, {'3', '1'}, set(), set(), set()]
# .
# .
# .
# 2
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'3', '1'}, set(), set(), set()]
# .
# .
# .
# 6
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, set(), set(), set()]
# .
# 6
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, set(), set()]
# .
# .
# .
# .
# 2
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, set(), {'2'}]
# 8
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, set(), {'8', '2'}]
# .
# .
# .
# .
# 4
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4'}, {'8', '2'}]
# 1
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4', '1'}, {'8', '2'}]
# 9
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4', '9', '1'}, {'8', '2'}]
# .
# .
# 5
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4', '9', '1'}, {'5', '8', '2'}]
# .
# .
# .
# .
# 8
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4', '8', '9', '1'}, {'5', '8', '2'}]
# .
# .
# 7
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4', '8', '9', '1'}, {'5', '7', '8', '2'}]
# 9
# boxes:  [{'9', '6', '3', '5', '8'}, {'5', '7', '9', '1'}, {'6'}, {'4', '7', '8'}, {'2', '6', '8', '3'}, {'6', '3', '1'}, {'6'}, {'4', '8', '9', '1'}, {'7', '9', '5', '8', '2'}]
# True
