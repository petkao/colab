# %%
import openai

# %%
openai.api_key = "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"

# %%
def chat_with_gpt(prompt, model="gpt-4"):
    response = openai.ChatCompletion.create(
        model=model,
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response['choices'][0]['message']['content']

# %%
# !pip install --upgrade openai

import openai

openai.api_key = "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"

def chat_with_gpt(prompt, model="gpt-4"):
    """Chats with the OpenAI GPT model using the new API.

    Args:
        prompt: The user's prompt.
        model: The GPT model to use (defaults to "gpt-4").

    Returns:
        The GPT model's response.
    """
    response = openai.chat.completions.create(  # Use openai.chat.completions
        model=model,
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content  # Access response data using dot notation

user_input = input("You: ")
response = chat_with_gpt(user_input)
print(f"GPT: {response}")
# Out:
# ...
# You: Hello world
# GPT: Hello! How can I assist you today?
