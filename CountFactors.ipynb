# %%
def countfactors(N):
    count=0
    countfactors = []
    for i in range(1,N+1):
        if N%i==0:
            count=count+1
            countfactors.append(i)
    print(countfactors)
    return count

# %%
print(countfactors(83))
# Out:
# [1, 83]
# 2

# %%
import numpy as np
a = np.zeros((1, 5))
print(f"a shape = {a.shape}, a = {a}")

a = np.zeros((2, 1))
print(f"a shape = {a.shape}, a = {a}")

a = np.random.random_sample((1, 1))
print(f"a shape = {a.shape}, a = {a}")
# Out:
# a shape = (1, 5), a = [[0. 0. 0. 0. 0.]]
# a shape = (2, 1), a = [[0.]
#  [0.]]
# a shape = (1, 1), a = [[0.67169945]]

# %%
print(1.37435e+06)
# Out:
# 1374350.0

# %%
a = float(9e-7)
print(a)
# Out:
# 9e-07

# %%
class Person:
    def __init__(self, name, age):
      self.name = name
      self.age = age

p1 = Person("John", 36)


print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
my_array = [7, 12, 9, 4, 11]
print(my_array[2])
# Out:
# 9

# %%
a = True
b = False
print(a)
# Out:
# True
