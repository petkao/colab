# %%
import time
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)

completion = client.chat.completions.create(
  model="meta/llama-3.1-8b-instruct",
  messages=[{"role":"user","content":"Write a limerick about the wonders of GPU computing."}],
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  stream=True
)

for chunk in completion:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")
  # Add a delay to reduce request rate
  time.sleep(0.5) # Wait for 0.5 seconds between chunks
# Out:
# There once was a GPU so fine,
# It computed with speed and design.
# It processed with ease,
# Massive data with expertise,
# And solved problems in no time divine.
